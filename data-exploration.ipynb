# %%
import numpy as np
import pandas as pd
from cmapPy.pandasGEXpress.parse import parse
from pathlib import Path

# %%
DATA_DIR = Path("./data")
BATCH1 = "2024_07_19_Batch1_normalized_feature_select_negcon_batch.gct"
BATCH2 = "2025_01_31_Batch2_normalized_feature_select_negcon_batch.gct"
BATCH3 = "2025_06_10_Batch3_normalized_feature_select_negcon_batch.gct"
BATCH4 = "2025_09_25_Batch4_normalized_feature_select_negcon_batch.gct"
BATCH5 = "2025_09_25_Batch5_normalized_feature_select_negcon_batch.gct"

# %%
def extract(path: Path):
    gct = parse(str(path))
    df = gct.data_df
    df = df.T
    print("Unique perturbations: ", gct.col_metadata_df["perturbation"].unique())
    return df, gct.col_metadata_df

# %%
# batch 1
batch1_df, batch1_metadata = extract(str(DATA_DIR / BATCH1))
batch1_df["label"] = batch1_metadata["perturbation"].apply(lambda x: 1 if x == "3F9KO" or x == "KO" else 0)
# Out:
# Unique perturbations:  ['5E5_WT' '3F9KO' 'WT' 'KO']
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
batch1_df.shape
# Out:
# (615, 480)

# %%
batch1_df
# Out:
# Index(['SAMPLE_0', 'SAMPLE_1', 'SAMPLE_2', 'SAMPLE_3', 'SAMPLE_4', 'SAMPLE_5',
#        'SAMPLE_6', 'SAMPLE_7', 'SAMPLE_8', 'SAMPLE_9',
#        ...
#        'SAMPLE_605', 'SAMPLE_606', 'SAMPLE_607', 'SAMPLE_608', 'SAMPLE_609',
#        'SAMPLE_610', 'SAMPLE_611', 'SAMPLE_612', 'SAMPLE_613', 'SAMPLE_614'],
#       dtype='object', name='cid', length=615)

# %%
batch2_df, batch2_metadata = extract(DATA_DIR / BATCH2)
# Out:
# Unique perturbations:  ['WT' nan 'SELENON_KO']
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
batch3_df, batch3_metadataa = extract(DATA_DIR / BATCH3)
# Out:
# Unique perturbations:  ['SELENON KO' 'WT']
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
batch4_df, batch4_metadata = extract(DATA_DIR / BATCH4)
# Out:
# Unique perturbations:  ['SELENON KO' 'WT']
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
# batch 5
batch5_df, batch5_metadata = extract(str(DATA_DIR / BATCH5))
# Out:
# Unique perturbations:  ['WT-Exon3' 'SELENON KO-Exon3' 'WT-Exon5' 'SELENON KO-Exon5']
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
batch5_df.head()
# Out:
# rid       Cells_AreaShape_Compactness  Cells_AreaShape_EulerNumber  \
# cid
# SAMPLE_0                       3.1509                     -0.46041
# SAMPLE_1                       2.7700                      2.63340
# SAMPLE_2                       2.3967                      2.63340
# SAMPLE_3                       2.6341                      2.63340
# SAMPLE_4                       2.0129                      1.51320
#
# rid       Cells_AreaShape_FormFactor  Cells_AreaShape_Orientation  \
# cid
# SAMPLE_0                     -1.9838                      1.77150
# SAMPLE_1                     -1.5833                     -0.82196
# SAMPLE_2                     -1.3447                     -0.93325
# SAMPLE_3                     -1.6044                     -2.34930
# SAMPLE_4                     -1.2465                      0.37190
#
# rid       Cells_AreaShape_Zernike_1_1  Cells_AreaShape_Zernike_2_0  \
# cid
# SAMPLE_0                     -0.84255                      -3.5581
# ...

# %%
batch5_df.shape
# Out:
# (560, 482)

# %%
batch5_metadata["perturbation"].unique()
# Out:
# array(['WT-Exon3', 'SELENON KO-Exon3', 'WT-Exon5', 'SELENON KO-Exon5'],
#       dtype=object)

# %%
batch4_df, batch4_metadata = extract(DATA_DIR / BATCH4)
# Out:
# Unique perturbations:  ['SELENON KO' 'WT']
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:251: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   row_metadata = row_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))
# /opt/conda/lib/python3.11/site-packages/cmapPy/pandasGEXpress/parse_gct.py:277: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   col_metadata = col_metadata.apply(lambda x: pd.to_numeric(x, errors="ignore"))

# %%
batch1_df.index = "B1_" + batch1_df.index.astype(str)
batch5_df.index = "B5_" + batch5_df.index.astype(str)

combined_df = pd.concat([batch1_df, batch5_df], axis=0, ignore_index=False, sort=False)
combined_df
# Out:
# rid            Cells_AreaShape_BoundingBoxMaximum_X  \
# cid
# B1_SAMPLE_0                                  2.8990
# B1_SAMPLE_1                                  2.7636
# B1_SAMPLE_2                                  1.6274
# B1_SAMPLE_3                                  2.5451
# B1_SAMPLE_4                                  2.1380
# ...                                             ...
# B5_SAMPLE_555                                   NaN
# B5_SAMPLE_556                                   NaN
# B5_SAMPLE_557                                   NaN
# B5_SAMPLE_558                                   NaN
# B5_SAMPLE_559                                   NaN
#
# rid            Cells_AreaShape_Compactness  Cells_AreaShape_EulerNumber  \
# cid
# B1_SAMPLE_0                        3.24220                     2.264700
# B1_SAMPLE_1                        2.43230                     1.480800
# B1_SAMPLE_2                        3.07760                     1.558000
# ...

# %%
combined_df.shape
# Out:
# (1175, 716)

# %%
combined_df.reset_index()
combined_df
# Out:
# rid            Cells_AreaShape_BoundingBoxMaximum_X  \
# cid
# B1_SAMPLE_0                                  2.8990
# B1_SAMPLE_1                                  2.7636
# B1_SAMPLE_2                                  1.6274
# B1_SAMPLE_3                                  2.5451
# B1_SAMPLE_4                                  2.1380
# ...                                             ...
# B5_SAMPLE_555                                   NaN
# B5_SAMPLE_556                                   NaN
# B5_SAMPLE_557                                   NaN
# B5_SAMPLE_558                                   NaN
# B5_SAMPLE_559                                   NaN
#
# rid            Cells_AreaShape_Compactness  Cells_AreaShape_EulerNumber  \
# cid
# B1_SAMPLE_0                        3.24220                     2.264700
# B1_SAMPLE_1                        2.43230                     1.480800
# B1_SAMPLE_2                        3.07760                     1.558000
# ...
